# %%
import time
import numpy as np
from numpy import newaxis
from keras.layers.core import Dense, Activation, Dropout
from keras.layers import CuDNNLSTM,BatchNormalization
from keras.layers.recurrent import LSTM
from keras.models import Sequential
from matplotlib import pyplot
from matplotlib import pyplot as plt
import pickle
# Out:
# C:\Users\ndrs\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def loss_plot(history):
    pyplot.plot(history.history['loss'], label='train')
    pyplot.plot(history.history['val_loss'], label='test')
    pyplot.legend()
    pyplot.show();
def plot_results_multiple(predicted_data, true_data,x_test_date, prediction_len):
    fig = plt.figure(facecolor='white')
    ax = fig.add_subplot(111)
    ax.plot(true_data, label='True Data')
    #Pad the list of predictions to shift it in the graph to it's correct start
    for i, data in enumerate(predicted_data):
        padding = [None for p in range(i * prediction_len)]
        plt.plot(padding + data, label='Prediction')
        plt.legend()
    plt.show();

# %%
def load_data(seq_len):
   
    data=pickle.load(open('processed_data.p', "rb" ))
    
    seat_data=data.loc[data['seatName']=='B5_9_1_05']
    seat_data=seat_data.sort_values(['Datetime'])
    seat_data=seat_data.drop(['Country','Location','Resource Type','floor','Department','seatName'],axis=1)
    seat_data.set_index('Datetime',inplace=True)
    trial_data=np.array(seat_data['Space'])

    
    #Add rows to columns based on the sequence length
    sequence_length = seq_len + 1
    result = []
    for index in range(len(trial_data) - sequence_length):
        result.append(trial_data[index: index + sequence_length])
    
    # shape is (row)4453, (sequence length) 11
    result = np.array(result)
    
    #Split data
    row = round(0.85 * result.shape[0])
    train = result[:int(row), :]
    
    #np.random.shuffle(train)
    # X train keeps all the rows but removes last column, col x row(:-1)
    x_train = train[:, :-1]
    # y train keeps the cols with ONLY the values of the missing row (-1)
    y_train = train[:, -1]
    x_test = result[int(row):, :-1]
    y_test = result[int(row):, -1]
    print(x_train.shape,y_train.shape,x_test.shape,y_test.shape,'before reshape')
    #reshape X train and X_test based on the required LSTM shape(samples,Timestep,Features)
        # Samples is the number of rows (can be considered batch size)
        # Timestep is the number of values per row (can be considered values in the batch)
        # features is the number of variables input
    x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
    x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))  
    print(x_train.shape,y_train.shape,x_test.shape,y_test.shape,'after reshape')
    x_test_date = seat_data.tail(len(x_test)).index
    
    return [x_train, y_train, x_test, y_test,x_test_date]

def build_model(layers):
    model = Sequential()
    #input shape follows the (sequence length,time)
    #input shape (Sequence length(50),num of features(1)), neurons=(seq len)50
    model.add(CuDNNLSTM( input_shape=(layers[1], layers[0]), units=layers[1]))
    model.add(Dense(layers[3]))
    model.add(Activation("sigmoid"))

    start = time.time()
    model.compile(loss="binary_crossentropy", optimizer="adam",metrics=["binary_accuracy",'sparse_categorical_accuracy'])
    print("> Compilation Time : ", time.time() - start)
    return model

def predict_sequences_multiple(model, data, window_size, prediction_len):
    #Predict sequence of 50 steps before shifting prediction run forward by 50 steps
    prediction_seqs = []
    # loop through built prediction batches (test data/pred size)
    for i in range(int(len(data)/prediction_len)):
        #current batch/sequence = test[prediction batch number*prediction length]
        curr_frame = data[i*prediction_len]
        #sample shape = (10,1)
        predicted = []
        # loop through prediction length to build multiple predictions
        for j in range(prediction_len):
            #predict current batch
            # cur_frame[newaxis,:,:] sample shape = (1,10,1)
            predicted.append(model.predict(curr_frame[newaxis,:,:])[0,0])
            #example result =  [0.011287009]
            #move current frame row by one forward
            curr_frame = curr_frame[1:]
            #insert previous prediction to current frame to predict next sequence
            curr_frame = np.insert(curr_frame, [window_size-1], predicted[-1], axis=0)
        prediction_seqs.append(predicted)
    return prediction_seqs

# %%
def make_prediction():
        global_start_time = time.time()
        epochs  = 100
        seq_len = 10
        #lstm_dim=50
        lstm_dim2=100
        batch_size=100
        #pred_len=10
        pred_len=seq_len
        print('> Loading data... ')

        X_train, y_train, X_test, y_test,x_test_date = load_data(seq_len)
        print('> Data Loaded. Compiling...')
        
        model = build_model([1, seq_len, lstm_dim2, 1])

        history=model.fit( X_train,y_train,batch_size=batch_size,shuffle=False,epochs=epochs,validation_split=0.10)

        predictions = predict_sequences_multiple(model, X_test, seq_len, pred_len)      
        print('Training duration (s) : ', time.time() - global_start_time)
        show_plot=True
        if show_plot==True:
            loss_plot(history)
            plot_results_multiple(predictions, y_test,x_test_date, seq_len)

# %%
make_prediction()
# Out:
# > Loading data...
# (3785, 10) (3785,) (668, 10) (668,) before reshape
# (3785, 10, 1) (3785,) (668, 10, 1) (668,) after reshape
# > Data Loaded. Compiling...
# > Compilation Time :  0.03008103370666504
# Train on 3406 samples, validate on 379 samples
# Epoch 1/100
# 3406/3406 [==============================] - 1s 172us/step - loss: 0.6560 - binary_accuracy: 0.8790 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.5879 - val_binary_accuracy: 0.8945 - val_sparse_categorical_accuracy: 0.8945
# Epoch 2/100
# 3406/3406 [==============================] - 0s 54us/step - loss: 0.5049 - binary_accuracy: 0.8790 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.3735 - val_binary_accuracy: 0.8945 - val_sparse_categorical_accuracy: 0.8945
# Epoch 3/100
# 3406/3406 [==============================] - 0s 53us/step - loss: 0.3394 - binary_accuracy: 0.8790 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.2759 - val_binary_accuracy: 0.8945 - val_sparse_categorical_accuracy: 0.8945
# Epoch 4/100
# 3406/3406 [==============================] - 0s 57us/step - loss: 0.2725 - binary_accuracy: 0.8852 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.2290 - val_binary_accuracy: 0.8971 - val_sparse_categorical_accuracy: 0.8945
# Epoch 5/100
# 3406/3406 [==============================] - 0s 55us/step - loss: 0.2414 - binary_accuracy: 0.9031 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.2072 - val_binary_accuracy: 0.9340 - val_sparse_categorical_accuracy: 0.8945
# Epoch 6/100
# 3406/3406 [==============================] - 0s 53us/step - loss: 0.2261 - binary_accuracy: 0.9031 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1976 - val_binary_accuracy: 0.9367 - val_sparse_categorical_accuracy: 0.8945
# Epoch 7/100
# 3406/3406 [==============================] - 0s 55us/step - loss: 0.2172 - binary_accuracy: 0.9066 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1927 - val_binary_accuracy: 0.9367 - val_sparse_categorical_accuracy: 0.8945
# Epoch 8/100
# 3406/3406 [==============================] - 0s 59us/step - loss: 0.2110 - binary_accuracy: 0.9084 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1896 - val_binary_accuracy: 0.9393 - val_sparse_categorical_accuracy: 0.8945
# Epoch 9/100
# 3406/3406 [==============================] - 0s 55us/step - loss: 0.2062 - binary_accuracy: 0.9107 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1872 - val_binary_accuracy: 0.9393 - val_sparse_categorical_accuracy: 0.8945
# Epoch 10/100
# 3406/3406 [==============================] - 0s 57us/step - loss: 0.2021 - binary_accuracy: 0.9110 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1853 - val_binary_accuracy: 0.9393 - val_sparse_categorical_accuracy: 0.8945
# Epoch 11/100
# 3406/3406 [==============================] - 0s 55us/step - loss: 0.1986 - binary_accuracy: 0.9122 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1836 - val_binary_accuracy: 0.9393 - val_sparse_categorical_accuracy: 0.8945
# Epoch 12/100
# 3406/3406 [==============================] - 0s 56us/step - loss: 0.1954 - binary_accuracy: 0.9140 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1821 - val_binary_accuracy: 0.9393 - val_sparse_categorical_accuracy: 0.8945
# Epoch 13/100
# 3406/3406 [==============================] - 0s 58us/step - loss: 0.1924 - binary_accuracy: 0.9169 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1807 - val_binary_accuracy: 0.9393 - val_sparse_categorical_accuracy: 0.8945
# Epoch 14/100
# 3406/3406 [==============================] - 0s 57us/step - loss: 0.1897 - binary_accuracy: 0.9178 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1794 - val_binary_accuracy: 0.9420 - val_sparse_categorical_accuracy: 0.8945
# Epoch 15/100
# 3406/3406 [==============================] - 0s 56us/step - loss: 0.1872 - binary_accuracy: 0.9181 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1781 - val_binary_accuracy: 0.9420 - val_sparse_categorical_accuracy: 0.8945
# Epoch 16/100
# 3406/3406 [==============================] - 0s 56us/step - loss: 0.1848 - binary_accuracy: 0.9196 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1770 - val_binary_accuracy: 0.9420 - val_sparse_categorical_accuracy: 0.8945
# Epoch 17/100
# 3406/3406 [==============================] - 0s 55us/step - loss: 0.1826 - binary_accuracy: 0.9210 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1759 - val_binary_accuracy: 0.9393 - val_sparse_categorical_accuracy: 0.8945
# Epoch 18/100
# 3406/3406 [==============================] - 0s 62us/step - loss: 0.1805 - binary_accuracy: 0.9231 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1748 - val_binary_accuracy: 0.9393 - val_sparse_categorical_accuracy: 0.8945
# Epoch 19/100
# 3406/3406 [==============================] - 0s 60us/step - loss: 0.1785 - binary_accuracy: 0.9251 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1739 - val_binary_accuracy: 0.9393 - val_sparse_categorical_accuracy: 0.8945
# Epoch 20/100
# 3406/3406 [==============================] - 0s 55us/step - loss: 0.1766 - binary_accuracy: 0.9266 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1729 - val_binary_accuracy: 0.9340 - val_sparse_categorical_accuracy: 0.8945
# Epoch 21/100
# 3406/3406 [==============================] - 0s 57us/step - loss: 0.1749 - binary_accuracy: 0.9284 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1721 - val_binary_accuracy: 0.9314 - val_sparse_categorical_accuracy: 0.8945
# Epoch 22/100
# 3406/3406 [==============================] - 0s 57us/step - loss: 0.1732 - binary_accuracy: 0.9289 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1713 - val_binary_accuracy: 0.9314 - val_sparse_categorical_accuracy: 0.8945
# Epoch 23/100
# 3406/3406 [==============================] - 0s 59us/step - loss: 0.1717 - binary_accuracy: 0.9298 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1705 - val_binary_accuracy: 0.9288 - val_sparse_categorical_accuracy: 0.8945
# Epoch 24/100
# 3406/3406 [==============================] - 0s 60us/step - loss: 0.1702 - binary_accuracy: 0.9301 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1698 - val_binary_accuracy: 0.9340 - val_sparse_categorical_accuracy: 0.8945
# Epoch 25/100
# 3406/3406 [==============================] - 0s 59us/step - loss: 0.1688 - binary_accuracy: 0.9298 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1692 - val_binary_accuracy: 0.9340 - val_sparse_categorical_accuracy: 0.8945
# Epoch 26/100
# 3406/3406 [==============================] - 0s 59us/step - loss: 0.1675 - binary_accuracy: 0.9304 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1686 - val_binary_accuracy: 0.9340 - val_sparse_categorical_accuracy: 0.8945
# Epoch 27/100
# 3406/3406 [==============================] - 0s 57us/step - loss: 0.1663 - binary_accuracy: 0.9319 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1680 - val_binary_accuracy: 0.9340 - val_sparse_categorical_accuracy: 0.8945
# Epoch 28/100
# 3406/3406 [==============================] - 0s 61us/step - loss: 0.1651 - binary_accuracy: 0.9339 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1675 - val_binary_accuracy: 0.9340 - val_sparse_categorical_accuracy: 0.8945
# Epoch 29/100
# 3406/3406 [==============================] - 0s 59us/step - loss: 0.1640 - binary_accuracy: 0.9345 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1670 - val_binary_accuracy: 0.9340 - val_sparse_categorical_accuracy: 0.8945
# Epoch 30/100
# 3406/3406 [==============================] - 0s 57us/step - loss: 0.1630 - binary_accuracy: 0.9369 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1666 - val_binary_accuracy: 0.9393 - val_sparse_categorical_accuracy: 0.8945
# Epoch 31/100
# 3406/3406 [==============================] - 0s 57us/step - loss: 0.1620 - binary_accuracy: 0.9372 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1662 - val_binary_accuracy: 0.9367 - val_sparse_categorical_accuracy: 0.8945
# Epoch 32/100
# 3406/3406 [==============================] - 0s 56us/step - loss: 0.1611 - binary_accuracy: 0.9372 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1658 - val_binary_accuracy: 0.9367 - val_sparse_categorical_accuracy: 0.8945
# Epoch 33/100
# 3406/3406 [==============================] - 0s 59us/step - loss: 0.1602 - binary_accuracy: 0.9372 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1654 - val_binary_accuracy: 0.9367 - val_sparse_categorical_accuracy: 0.8945
# Epoch 34/100
# 3406/3406 [==============================] - 0s 55us/step - loss: 0.1594 - binary_accuracy: 0.9372 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1651 - val_binary_accuracy: 0.9367 - val_sparse_categorical_accuracy: 0.8945
# Epoch 35/100
# 3406/3406 [==============================] - 0s 55us/step - loss: 0.1586 - binary_accuracy: 0.9372 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1647 - val_binary_accuracy: 0.9367 - val_sparse_categorical_accuracy: 0.8945
# Epoch 36/100
# 3406/3406 [==============================] - 0s 56us/step - loss: 0.1579 - binary_accuracy: 0.9381 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1644 - val_binary_accuracy: 0.9367 - val_sparse_categorical_accuracy: 0.8945
# Epoch 37/100
# 3406/3406 [==============================] - 0s 55us/step - loss: 0.1572 - binary_accuracy: 0.9381 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1641 - val_binary_accuracy: 0.9367 - val_sparse_categorical_accuracy: 0.8945
# Epoch 38/100
# 3406/3406 [==============================] - 0s 55us/step - loss: 0.1565 - binary_accuracy: 0.9395 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1639 - val_binary_accuracy: 0.9367 - val_sparse_categorical_accuracy: 0.8945
# Epoch 39/100
# 3406/3406 [==============================] - 0s 57us/step - loss: 0.1559 - binary_accuracy: 0.9398 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1636 - val_binary_accuracy: 0.9367 - val_sparse_categorical_accuracy: 0.8945
# Epoch 40/100
# 3406/3406 [==============================] - 0s 55us/step - loss: 0.1553 - binary_accuracy: 0.9407 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1634 - val_binary_accuracy: 0.9367 - val_sparse_categorical_accuracy: 0.8945
# Epoch 41/100
# 3406/3406 [==============================] - 0s 56us/step - loss: 0.1547 - binary_accuracy: 0.9407 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1631 - val_binary_accuracy: 0.9367 - val_sparse_categorical_accuracy: 0.8945
# Epoch 42/100
# 3406/3406 [==============================] - 0s 54us/step - loss: 0.1542 - binary_accuracy: 0.9413 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1629 - val_binary_accuracy: 0.9367 - val_sparse_categorical_accuracy: 0.8945
# Epoch 43/100
# 3406/3406 [==============================] - 0s 57us/step - loss: 0.1537 - binary_accuracy: 0.9416 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1627 - val_binary_accuracy: 0.9367 - val_sparse_categorical_accuracy: 0.8945
# Epoch 44/100
# 3406/3406 [==============================] - 0s 54us/step - loss: 0.1532 - binary_accuracy: 0.9419 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1626 - val_binary_accuracy: 0.9367 - val_sparse_categorical_accuracy: 0.8945
# Epoch 45/100
# 3406/3406 [==============================] - 0s 55us/step - loss: 0.1528 - binary_accuracy: 0.9427 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1624 - val_binary_accuracy: 0.9367 - val_sparse_categorical_accuracy: 0.8945
# Epoch 46/100
# 3406/3406 [==============================] - 0s 55us/step - loss: 0.1523 - binary_accuracy: 0.9427 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1622 - val_binary_accuracy: 0.9367 - val_sparse_categorical_accuracy: 0.8945
# Epoch 47/100
# 3406/3406 [==============================] - 0s 54us/step - loss: 0.1519 - binary_accuracy: 0.9436 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1621 - val_binary_accuracy: 0.9367 - val_sparse_categorical_accuracy: 0.8945
# Epoch 48/100
# 3406/3406 [==============================] - 0s 54us/step - loss: 0.1515 - binary_accuracy: 0.9448 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1619 - val_binary_accuracy: 0.9393 - val_sparse_categorical_accuracy: 0.8945
# Epoch 49/100
# 3406/3406 [==============================] - 0s 56us/step - loss: 0.1512 - binary_accuracy: 0.9448 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1618 - val_binary_accuracy: 0.9420 - val_sparse_categorical_accuracy: 0.8945
# Epoch 50/100
# 3406/3406 [==============================] - 0s 55us/step - loss: 0.1508 - binary_accuracy: 0.9466 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1617 - val_binary_accuracy: 0.9420 - val_sparse_categorical_accuracy: 0.8945
# Epoch 51/100
# 3406/3406 [==============================] - 0s 53us/step - loss: 0.1505 - binary_accuracy: 0.9463 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.1615 - val_binary_accuracy: 0.9420 - val_sparse_categorical_accuracy: 0.8945
# Epoch 52/100
# 3406/3406 [==============================] - 0s 55us/step - loss: 0.