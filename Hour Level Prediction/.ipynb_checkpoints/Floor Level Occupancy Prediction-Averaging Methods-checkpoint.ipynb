# %%
import time
import numpy as np
from matplotlib import pyplot
from matplotlib import pyplot as plt
import pickle
import pandas as pd
import IPython.display as display

# %%
data_list=['Barclays-Noida-3.2-Jan', 'Barclays-Noida-3.2-Feb', 'Barclays-Noida-3.2-March','Barclays-Noida-3.2-April']

for month in range(len(data_list)):
    month_data=pickle.load(open('../../processed_data/'+data_list[month]+'.p', "rb" ))
    if month==0:
        data=month_data.copy()
    else:
        data=pd.concat([data,month_data])
data=data.drop(['Country','Department','Resource Type'],axis=1)

# %%
data=data.groupby([data.floor,data.seatName,pd.Grouper(key='Datetime',freq='H')])
data=data['Space'].agg([np.sum])
data.reset_index(inplace=True)
data['isOccupied']=[0 if x <3 else 1 for x in data['sum']]
data=data.drop(['sum'],axis=1)
floor_data=data.groupby([data.floor,pd.Grouper(key='Datetime',freq='H')])['isOccupied'].agg([np.sum])
floor_data.reset_index(inplace=True)
one_floor=floor_data.loc[floor_data.floor=='Level 9']
one_floor.set_index('Datetime',inplace=True)
one_floor.index.freq='H'
one_floor.head(3)
# Out:
#                        floor  sum
# Datetime
# 2018-01-29 00:00:00  Level 9   23
# 2018-01-29 01:00:00  Level 9   21
# 2018-01-29 02:00:00  Level 9   14

# %%
from sklearn.metrics import log_loss,mean_squared_log_error,r2_score,mean_squared_error
from math import sqrt

def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def metric_scores(y_true, y_pred):
    mse=mean_squared_error(y_true,y_pred)
    #msle=mean_squared_log_error(y_true,y_pred)
    rmse = sqrt(mean_squared_error(y_true,y_pred))
    r2=r2_score(y_true,y_pred)
    mape=mean_absolute_percentage_error(y_true,y_pred)
    #print('msle',msle)
    print('rmse',rmse)
    print('mse',mse)
    print('mape',mape)
    print('r2',r2)
def plot_data(y_hat):
    
    #plt.figure(figsize=(12,8))
    #plt.plot(train['Space'], label='Train')
    plt.plot(y_hat['sum'], label='Test')
    plt.plot(y_hat['avg_forecast'], label='Average Forecast')
    plt.legend(loc='best')
    plt.show()

# %%
date_split='2018-04-24'
train,test=one_floor.loc[one_floor.index<date_split],one_floor.loc[one_floor.index>=date_split]

# %%
y_hat_avg=test.copy()
pred_list=[]
for i in range(7):
    day_floor_data= train.loc[train.index.weekday==i]
    daterange = pd.date_range('00:00', '23:00',freq='H')
    for date in daterange:
        list_index=day_floor_data.index.indexer_at_time(date, asof=False)
        day_min_floor_data=day_floor_data.iloc[list_index]
        pred_list.append(day_min_floor_data['sum'].mean())
        
y_hat_avg['avg_forecast'] =pred_list
plot_data(y_hat_avg)
metric_scores(y_hat_avg['sum'],y_hat_avg['avg_forecast'])
# Out:
# msle 0.6129599402128201
# rmse 64.82139941799106
# mape 57.11529772705679

# %%
y_hat_avg=test.copy()
pred_list=[]
for i in range(7):
    day_floor_data= train.loc[train.index.weekday==i]
    daterange = pd.date_range('00:00', '23:00',freq='H')
    for date in daterange:
        list_index=day_floor_data.index.indexer_at_time(date, asof=False)
        day_min_floor_data=day_floor_data.iloc[list_index]
        pred_list.append(day_min_floor_data['sum'].rolling(3).mean().iloc[-1])

y_hat_avg['avg_forecast'] =pred_list
plot_data(y_hat_avg)
metric_scores(y_hat_avg['sum'],y_hat_avg['avg_forecast'])
# Out:
# msle 0.7822924380147634
# rmse 71.5652983730029
# mape 58.762475845650265

# %%
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
y_hat_avg=test.copy()
pred_list=[]
for i in range(7):
    day_floor_data= train.loc[train.index.weekday==i]
    daterange = pd.date_range('00:00', '23:00',freq='H')
    for date in daterange:
        list_index=day_floor_data.index.indexer_at_time(date, asof=False)
        day_min_floor_data=day_floor_data.iloc[list_index]
        fit2 = SimpleExpSmoothing(np.asarray(day_min_floor_data['sum'])).fit(smoothing_level=0.2,optimized=True)
        pred_list.append(fit2.forecast(1))

y_hat_avg['avg_forecast'] =pred_list
plot_data(y_hat_avg)
metric_scores(y_hat_avg['sum'],y_hat_avg['avg_forecast'])
# Out:
# msle 0.6072312759985122
# rmse 65.6353343836694
# mape [54.00064138]

# %%
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
y_hat_avg=test.copy()
pred_list=[]
for i in range(7):
    day_floor_data= train.loc[train.index.weekday==i]
    daterange = pd.date_range('00:00', '23:00',freq='H')
    for date in daterange:
        list_index=day_floor_data.index.indexer_at_time(date, asof=False)
        day_min_floor_data=day_floor_data.iloc[list_index]
        fit1 = Holt(np.asarray(day_min_floor_data['sum'])).fit(smoothing_level = 0.3,smoothing_slope = 0.1)
        pred_list.append(fit1.forecast(1))
        

y_hat_avg['avg_forecast'] =pred_list
plot_data(y_hat_avg)
metric_scores(y_hat_avg['sum'],y_hat_avg['avg_forecast'])
# Out:
# msle 0.6750069565788287
# rmse 67.89832822450992
# mape [53.81185553]
