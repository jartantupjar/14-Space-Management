# %%
import time
import numpy as np
from numpy import newaxis
from keras.layers.core import Dense, Activation, Dropout
from keras.layers import CuDNNLSTM,BatchNormalization
from keras.layers.recurrent import LSTM
from keras.models import Sequential
from matplotlib import pyplot
from matplotlib import pyplot as plt
import pickle
import pandas as pd
# Out:
# C:\Users\ndrs\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def loss_plot(history):
    pyplot.plot(history.history['loss'], label='train')
    pyplot.plot(history.history['val_loss'], label='test')
    pyplot.legend()
    pyplot.show();
def plot_results_multiple(predicted_data, true_data,x_test_date, prediction_len):
    fig = plt.figure(facecolor='white')
    ax = fig.add_subplot(111)
    ax.plot(true_data, label='True Data')
    #Pad the list of predictions to shift it in the graph to it's correct start
    for i, data in enumerate(predicted_data):
        padding = [None for p in range(i * prediction_len)]
        plt.plot(padding + data, label='Prediction')
        plt.legend()
    plt.show();

# %%
def load_data(seq_len):
   
   # data=pickle.load(open('processed_data.p', "rb" ))
    data_list=['Barclays-Noida-3.2-Jan', 'Barclays-Noida-3.2-Feb', 'Barclays-Noida-3.2-March','Barclays-Noida-3.2-April']

    for month in range(len(data_list)):
        month_data=pickle.load(open('../processed_data/'+data_list[month]+'.p', "rb" ))
        if month==0:
            data=month_data.copy()
        else:
            data=pd.concat([data,month_data])
    data=data.drop(['Country','Department','Resource Type'],axis=1)

    data=data.groupby([data.floor,data.seatName,pd.Grouper(key='Datetime',freq='H')])
    data=data['Space'].agg([np.sum])
    data.reset_index(inplace=True)
    data['isOccupied']=[0 if x <3 else 1 for x in data['sum']]
    data=data.drop(['sum'],axis=1)
    floor_data=data.groupby([data.floor,pd.Grouper(key='Datetime',freq='H')])['isOccupied'].agg([np.sum])
    floor_data.reset_index(inplace=True)
    one_floor=floor_data.loc[floor_data.floor=='Level 9']
    one_floor.set_index('Datetime',inplace=True)
    one_floor.index.freq='H'
    trial_data=np.array(one_floor['sum'])

    
    #Add rows to columns based on the sequence length
    sequence_length = seq_len + 1
    result = []
    for index in range(len(trial_data) - sequence_length):
        result.append(trial_data[index: index + sequence_length])
    
    # shape is (row)4453, (sequence length) 11
    result = np.array(result)
    
    #Split data
    print('len size',result.shape[0])
    row = round(0.90* result.shape[0])
    train = result[:int(row), :]
    
    #np.random.shuffle(train)
    # X train keeps all the rows but removes last column, col x row(:-1)
    x_train = train[:, :-1]
    # y train keeps the cols with ONLY the values of the missing row (-1)
    y_train = train[:, -1]
    x_test = result[int(row):, :-1]
    y_test = result[int(row):, -1]
    print(x_train.shape,y_train.shape,x_test.shape,y_test.shape,'before reshape')
    #reshape X train and X_test based on the required LSTM shape(samples,Timestep,Features)
        # Samples is the number of rows (can be considered batch size)
        # Timestep is the number of values per row (can be considered values in the batch)
        # features is the number of variables input
    x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
    x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))  
    print(x_train.shape,y_train.shape,x_test.shape,y_test.shape,'after reshape')
    x_test_date = one_floor.tail(len(x_test)).index
    
    return [x_train, y_train, x_test, y_test,x_test_date]

def build_model(layers):
    model = Sequential()
    #input shape follows the (sequence length,time)
    #input shape (Sequence length(50),num of features(1)), neurons=(seq len)50
    model.add(CuDNNLSTM( input_shape=(layers[1], layers[0]), units=layers[1]))
    model.add(Dense(layers[3]))
    model.add(Activation("sigmoid"))

    start = time.time()
    model.compile(loss="binary_crossentropy", optimizer="adam",metrics=["binary_accuracy",'sparse_categorical_accuracy'])
    print("> Compilation Time : ", time.time() - start)
    return model

def predict_sequences_multiple(model, data, window_size, prediction_len):
    #Predict sequence of 50 steps before shifting prediction run forward by 50 steps
    prediction_seqs = []
    # loop through built prediction batches (test data/pred size)
    for i in range(int(len(data)/prediction_len)):
        #current batch/sequence = test[prediction batch number*prediction length]
        curr_frame = data[i*prediction_len]
        #sample shape = (10,1)
        predicted = []
        # loop through prediction length to build multiple predictions
        for j in range(prediction_len):
            #predict current batch
            # cur_frame[newaxis,:,:] sample shape = (1,10,1)
            predicted.append(model.predict(curr_frame[newaxis,:,:])[0,0])
            #example result =  [0.011287009]
            #move current frame row by one forward
            curr_frame = curr_frame[1:]
            #insert previous prediction to current frame to predict next sequence
            curr_frame = np.insert(curr_frame, [window_size-1], predicted[-1], axis=0)
        prediction_seqs.append(predicted)
    return prediction_seqs

# %%
def make_prediction():
        global_start_time = time.time()
        epochs  = 100
        seq_len = 10
        #lstm_dim=50
        lstm_dim2=100
        batch_size=50
        #pred_len=10
        pred_len=seq_len
        print('> Loading data... ')

        X_train, y_train, X_test, y_test,x_test_date = load_data(seq_len)
        print('> Data Loaded. Compiling...')
        
        model = build_model([1, seq_len, lstm_dim2, 1])

        history=model.fit( X_train,y_train,batch_size=batch_size,shuffle=False,epochs=epochs,validation_split=0.20)

        predictions = predict_sequences_multiple(model, X_test, seq_len, pred_len)      
        print('Training duration (s) : ', time.time() - global_start_time)
        show_plot=True
        if show_plot==True:
            loss_plot(history)
            plot_results_multiple(predictions, y_test,x_test_date, seq_len)

# %%
make_prediction()
# Out:
# > Loading data...
# len size 2107
# (1896, 100) (1896,) (211, 100) (211,) before reshape
# (1896, 100, 1) (1896,) (211, 100, 1) (211,) after reshape
# > Data Loaded. Compiling...
# > Compilation Time :  0.04010653495788574
# Train on 1516 samples, validate on 380 samples
# Epoch 1/100
# 1516/1516 [==============================] - 1s 515us/step - loss: -161.9458 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -295.0865 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 2/100
# 1516/1516 [==============================] - 0s 186us/step - loss: -590.0681 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -796.9166 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 3/100
# 1516/1516 [==============================] - 0s 177us/step - loss: -1069.2849 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 4/100
# 1516/1516 [==============================] - 0s 181us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 5/100
# 1516/1516 [==============================] - 0s 183us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 6/100
# 1516/1516 [==============================] - 0s 183us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 7/100
# 1516/1516 [==============================] - 0s 185us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 8/100
# 1516/1516 [==============================] - 0s 183us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 9/100
# 1516/1516 [==============================] - 0s 187us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 10/100
# 1516/1516 [==============================] - 0s 178us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 11/100
# 1516/1516 [==============================] - 0s 183us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 12/100
# 1516/1516 [==============================] - 0s 178us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 13/100
# 1516/1516 [==============================] - 0s 181us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 14/100
# 1516/1516 [==============================] - 0s 177us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 15/100
# 1516/1516 [==============================] - 0s 182us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 16/100
# 1516/1516 [==============================] - 0s 186us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 17/100
# 1516/1516 [==============================] - 0s 183us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 18/100
# 1516/1516 [==============================] - 0s 177us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 19/100
# 1516/1516 [==============================] - 0s 179us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 20/100
# 1516/1516 [==============================] - 0s 183us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 21/100
# 1516/1516 [==============================] - 0s 181us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 22/100
# 1516/1516 [==============================] - 0s 181us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 23/100
# 1516/1516 [==============================] - 0s 183us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 24/100
# 1516/1516 [==============================] - 0s 179us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 25/100
# 1516/1516 [==============================] - 0s 188us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 26/100
# 1516/1516 [==============================] - 0s 181us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 27/100
# 1516/1516 [==============================] - 0s 186us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 28/100
# 1516/1516 [==============================] - 0s 179us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 29/100
# 1516/1516 [==============================] - 0s 184us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 30/100
# 1516/1516 [==============================] - 0s 179us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 31/100
# 1516/1516 [==============================] - 0s 177us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 32/100
# 1516/1516 [==============================] - 0s 185us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 33/100
# 1516/1516 [==============================] - 0s 189us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 34/100
# 1516/1516 [==============================] - 0s 179us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 35/100
# 1516/1516 [==============================] - 0s 183us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 36/100
# 1516/1516 [==============================] - 0s 182us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 37/100
# 1516/1516 [==============================] - 0s 182us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 38/100
# 1516/1516 [==============================] - 0s 196us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 39/100
# 1516/1516 [==============================] - 0s 179us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 40/100
# 1516/1516 [==============================] - 0s 176us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 41/100
# 1516/1516 [==============================] - 0s 181us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 42/100
# 1516/1516 [==============================] - 0s 193us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 43/100
# 1516/1516 [==============================] - 0s 185us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 44/100
# 1516/1516 [==============================] - 0s 181us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 45/100
# 1516/1516 [==============================] - 0s 184us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 46/100
# 1516/1516 [==============================] - 0s 185us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 47/100
# 1516/1516 [==============================] - 0s 182us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 48/100
# 1516/1516 [==============================] - 0s 177us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 49/100
# 1516/1516 [==============================] - 0s 184us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 50/100
# 1516/1516 [==============================] - 0s 185us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 51/100
# 1516/1516 [==============================] - 0s 179us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 52/100
# 1516/1516 [==============================] - 0s 185us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 53/100
# 1516/1516 [==============================] - 0s 183us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 54/100
# 1516/1516 [==============================] - 0s 188us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 55/100
# 1516/1516 [==============================] - 0s 181us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 56/100
# 1516/1516 [==============================] - 0s 179us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 57/100
# 1516/1516 [==============================] - 0s 181us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 58/100
# 1516/1516 [==============================] - 0s 185us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 59/100
# 1516/1516 [==============================] - 0s 183us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 60/100
# 1516/1516 [==============================] - 0s 178us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 61/100
# 1516/1516 [==============================] - 0s 183us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 62/100
# 1516/1516 [==============================] - 0s 187us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 63/100
# 1516/1516 [==============================] - 0s 182us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 64/100
# 1516/1516 [==============================] - 0s 177us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 65/100
# 1516/1516 [==============================] - 0s 182us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 66/100
# 1516/1516 [==============================] - 0s 187us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 67/100
# 1516/1516 [==============================] - 0s 181us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 68/100
# 1516/1516 [==============================] - 0s 183us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 69/100
# 1516/1516 [==============================] - 0s 183us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 70/100
# 1516/1516 [==============================] - 0s 182us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 71/100
# 1516/1516 [==============================] - 0s 181us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 72/100
# 1516/1516 [==============================] - 0s 185us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 73/100
# 1516/1516 [==============================] - 0s 183us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 74/100
# 1516/1516 [==============================] - 0s 185us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 75/100
# 1516/1516 [==============================] - 0s 180us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 76/100
# 1516/1516 [==============================] - 0s 185us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 77/100
# 1516/1516 [==============================] - 0s 188us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 78/100
# 1516/1516 [==============================] - 0s 185us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 79/100
# 1516/1516 [==============================] - 0s 181us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 80/100
# 1516/1516 [==============================] - 0s 184us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 81/100
# 1516/1516 [==============================] - 0s 184us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 82/100
# 1516/1516 [==============================] - 0s 182us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 83/100
# 1516/1516 [==============================] - 0s 179us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 84/100
# 1516/1516 [==============================] - 0s 184us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 85/100
# 1516/1516 [==============================] - 0s 181us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 86/100
# 1516/1516 [==============================] - 0s 187us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 87/100
# 1516/1516 [==============================] - 0s 184us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 88/100
# 1516/1516 [==============================] - 0s 185us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 89/100
# 1516/1516 [==============================] - 0s 183us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 90/100
# 1516/1516 [==============================] - 0s 187us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 91/100
# 1516/1516 [==============================] - 0s 187us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 92/100
# 1516/1516 [==============================] - 0s 186us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 93/100
# 1516/1516 [==============================] - 0s 184us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 94/100
# 1516/1516 [==============================] - 0s 187us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 95/100
# 1516/1516 [==============================] - 0s 187us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 96/100
# 1516/1516 [==============================] - 0s 185us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 97/100
# 1516/1516 [==============================] - 0s 184us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 98/100
# 1516/1516 [==============================] - 0s 182us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 99/100
# 1516/1516 [==============================] - 0s 179us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Epoch 100/100
# 1516/1516 [==============================] - 0s 179us/step - loss: -1140.2170 - binary_accuracy: 0.0066 - sparse_categorical_accuracy: 0.0567 - val_loss: -1038.3527 - val_binary_accuracy: 0.0026 - val_sparse_categorical_accuracy: 0.2684
# Training duration (s) :  66.43063759803772
